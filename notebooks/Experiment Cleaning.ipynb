# %%
import pandas as pd
import numpy as np
import os
import re
from collections import defaultdict

# %%
! ls ../experiments/networks/alarm/ges
# Out:
# ls: ../experiments/networks/alarm/ges: No such file or directory

# %%
for root, dirs, files in os.walk("."):
    for d in dirs:
        print(os.path.relpath(os.path.join(root, d), "."))
    for f in files:
        print(os.path.relpath(os.path.join(root, f), "."))
# Out:
# .ipynb_checkpoints
# Experiment Cleaning.ipynb
# .ipynb_checkpoints/Experiment Cleaning-checkpoint.ipynb

# %%
data_folder = "../experiments/local/raw/networks/"
networks = ["alarm"]#, "cancer", "earthquake", "mildew", "barley", "child", "insurance", "water"]
algorithms = ["ges", "hc", "pfhcbes", "pges", "phc"]
data_size = ["10k", "50k"]
threads = [2, 4, 6, 8]
interleaving = [5, 10, 15]
threads_str = list(map(lambda x: "T" + str(x), threads))
interleaving_str = list(map(lambda x: "I" + str(x), interleaving))

ending = "_global_results.csv"

# %%
comment = """
experiments = {}
for net in networks:
    experiments[net] = {}
    for alg in algorithms:
        net_paths = []
        experiments[net][alg] = {}
        
        for root, _, files in os.walk(data_folder + net + "/" + alg):
            for f in files:
                net_paths.append(os.path.relpath(os.path.join(root, f), "."))
        experiments[net][alg]["paths"] = net_paths
"""

# %%
experiments = {}
for net in networks:
    experiments[net] = {}
    net_paths = []
    for alg in algorithms:
        experiments[net][alg] = {}
        for size in data_size:
            experiments[net][alg][size] = {}
            if alg != "ges":
                for thread in threads_str:
                    experiments[net][alg][size][thread] = {}
                    for inter in interleaving_str:
                        experiments[net][alg][size][thread][inter] = {}
                        path = data_folder + net +"/"+ alg + "/" + net \
                                + size + str(thread) + "_" + str(inter) +  ending
                        experiments[net][alg][size][thread][inter]["path"] = path
                        experiments[net][alg][size][thread][inter]["data"] = pd.read_csv(path)
            else:
                path = data_folder + net +"/"+ alg + "/" + net \
                                + size + ending
                experiments[net][alg][size]["path"] = path
                experiments[net][alg][size]["data"] = pd.read_csv(path)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(experiments)
# Out:
# {   'alarm': {   'ges': {   '10k': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total time(s)
# 0   16 -110492.244849  1.027027       12.0        26.0              1,
#                                        'path': '../experiments/local/raw/networks/alarm/ges/alarm10k_global_results.csv'},
#                             '50k': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total time(s)
# 0    8 -529624.355066  0.378378        6.0         8.0              2,
#                                        'path': '../experiments/local/raw/networks/alarm/ges/alarm50k_global_results.csv'}},
#                  'hc': {   '10k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT2_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT2_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                11
#
#    Total time(s)
# 0              1  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT2_I5_global_results.csv'}},
#                                       'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT4_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT4_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                11
#
#    Total time(s)
# 0              1  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT4_I5_global_results.csv'}},
#                                       'T6': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT6_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT6_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                11
#
#    Total time(s)
# 0              0  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT6_I5_global_results.csv'}},
#                                       'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT8_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT8_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -111830.872655  1.783784       32.0        34.0                11
#
#    Total time(s)
# 0              0  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm10kT8_I5_global_results.csv'}}},
#                            '50k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#    Total time(s)
# 0              3  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT2_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT2_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                13
#
#    Total time(s)
# 0              2  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT2_I5_global_results.csv'}},
#                                       'T4': {   'I10': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT4_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT4_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                13
#
#    Total time(s)
# 0              2  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT4_I5_global_results.csv'}},
#                                       'T6': {   'I10': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT6_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT6_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                13
#
#    Total time(s)
# 0              2  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT6_I5_global_results.csv'}},
#                                       'T8': {   'I10': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT8_I10_global_results.csv'},
#                                                 'I15': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT8_I15_global_results.csv'},
#                                                 'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -533177.548165  1.72973       46.0        18.0                13
#
#    Total time(s)
# 0              2  ,
#                                                           'path': '../experiments/local/raw/networks/alarm/hc/alarm50kT8_I5_global_results.csv'}}}},
#                  'pfhcbes': {   '10k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   24 -110557.756724  1.135135       18.0        24.0                 9
#
#    Total time(s)
# 0              0  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT2_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   35 -110479.934647  1.351351       28.0        22.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT2_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   11 -109670.733751  0.756757        2.0        26.0                10
#
#    Total time(s)
# 0              0  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT2_I5_global_results.csv'}},
#                                            'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   28 -111235.366562  1.513514       26.0        30.0                 7
#
#    Total time(s)
# 0              0  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT4_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   34 -111102.293374  2.162162       40.0        40.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT4_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   45 -111983.170636  1.891892       26.0        44.0                 7
#
#    Total time(s)
# 0              0  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT4_I5_global_results.csv'}},
#                                            'T6': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   30 -111385.352403  1.675676       40.0        22.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT6_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   30 -111847.683346  1.621622       28.0        32.0                 4
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT6_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   25 -111168.610524  1.621622       24.0        36.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT6_I5_global_results.csv'}},
#                                            'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   30 -110886.291218  1.675676       26.0        36.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT8_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   39 -111640.698619  1.945946       36.0        36.0                 8
#
#    Total time(s)
# 0              2  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT8_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   38 -110981.442702  1.837838       30.0        38.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm10kT8_I5_global_results.csv'}}},
#                                 '50k': {   'T2': {   'I10': {   'data':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   35 -533685.85961  1.837838       38.0        30.0                 8
#
#    Total time(s)
# 0              2  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT2_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   39 -535553.120535  2.054054       56.0        20.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT2_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   11 -529529.496734  0.486486        6.0        12.0                10
#
#    Total time(s)
# 0              3  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT2_I5_global_results.csv'}},
#                                            'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   35 -536630.462198  1.783784       54.0        12.0                 5
#
#    Total time(s)
# 0              2  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT4_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   49 -536447.307654  2.378378       62.0        26.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT4_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   19 -528795.945958  0.756757       14.0        14.0                 9
#
#    Total time(s)
# 0              1  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT4_I5_global_results.csv'}},
#                                            'T6': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   24 -531720.525949  1.675676       42.0        20.0                 4
#
#    Total time(s)
# 0              1  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT6_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   28 -530099.994618  1.189189       22.0        22.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT6_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   25 -532060.262368  1.72973       40.0        24.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT6_I5_global_results.csv'}},
#                                            'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   70 -533688.958979  3.243243       98.0        22.0                 5
#
#    Total time(s)
# 0              4  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT8_I10_global_results.csv'},
#                                                      'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   34 -533241.868645  1.837838       56.0        12.0                 6
#
#    Total time(s)
# 0              3  ,
#                                                                 'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT8_I15_global_results.csv'},
#                                                      'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   18 -532762.811722  1.081081       24.0        16.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                                'path': '../experiments/local/raw/networks/alarm/pfhcbes/alarm50kT8_I5_global_results.csv'}}}},
#                  'pges': {   '10k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   13 -110141.116831  0.594595        6.0        16.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT2_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   32 -111129.283677  1.459459       24.0        30.0                11
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT2_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   17 -110675.386019  0.972973        8.0        28.0                 8
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT2_I5_global_results.csv'}},
#                                         'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   23 -111007.220105  1.135135       14.0        28.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT4_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   23 -111837.297253  1.297297       16.0        32.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT4_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   26 -111050.058523  1.567568       20.0        38.0                10
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT4_I5_global_results.csv'}},
#                                         'T6': {   'I10': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   28 -111293.127349  1.72973       24.0        40.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT6_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -111479.649091  1.72973       22.0        42.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT6_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   32 -111532.801004  1.675676       26.0        36.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT6_I5_global_results.csv'}},
#                                         'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   27 -111877.347033  1.621622       26.0        34.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT8_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   34 -112291.861226  2.054054       36.0        40.0                 7
#
#    Total time(s)
# 0              3  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT8_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   21 -110046.727419  1.351351       14.0        36.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm10kT8_I5_global_results.csv'}}},
#                              '50k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   18 -529978.942184  1.243243       28.0        18.0                 9
#
#    Total time(s)
# 0              3  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT2_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   11 -531090.598115  0.540541       10.0        10.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT2_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0    6 -528437.800533  0.216216        0.0         8.0                10
#
#    Total time(s)
# 0              3  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT2_I5_global_results.csv'}},
#                                         'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   11 -529366.302438  0.486486        8.0        10.0                 7
#
#    Total time(s)
# 0              2  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT4_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   22 -531643.351219  1.189189       28.0        16.0                 8
#
#    Total time(s)
# 0              5  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT4_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   25 -531355.95047  1.567568       40.0        18.0                10
#
#    Total time(s)
# 0              3  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT4_I5_global_results.csv'}},
#                                         'T6': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   16 -529359.546259  0.594595        6.0        16.0                10
#
#    Total time(s)
# 0              4  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT6_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   17 -530188.016709  1.081081       30.0        10.0                 6
#
#    Total time(s)
# 0              4  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT6_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   16 -528843.841769  0.648649        8.0        16.0                 8
#
#    Total time(s)
# 0              4  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT6_I5_global_results.csv'}},
#                                         'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   25 -532286.177538  1.675676       46.0        16.0                 5
#
#    Total time(s)
# 0              3  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT8_I10_global_results.csv'},
#                                                   'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   37 -532151.921336  1.405405       38.0        14.0                 8
#
#    Total time(s)
# 0              3  ,
#                                                              'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT8_I15_global_results.csv'},
#                                                   'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   31 -530428.702596  1.891892       54.0        16.0                 6
#
#    Total time(s)
# 0              3  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/pges/alarm50kT8_I5_global_results.csv'}}}},
#                  'phc': {   '10k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   31 -111012.214487  1.513514       30.0        26.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT2_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   48 -111942.205209  1.837838       38.0        30.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT2_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   26 -111178.167331  1.675676       26.0        36.0                 8
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT2_I5_global_results.csv'}},
#                                        'T4': {   'I10': {   'data':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   42 -112815.15958  2.378378       52.0        36.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT4_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   28 -110847.547022  1.513514       24.0        32.0                 3
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT4_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   21 -110455.555029  1.081081       14.0        26.0                 6
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT4_I5_global_results.csv'}},
#                                        'T6': {   'I10': {   'data':    SHD     BDeu Score  dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   32 -111677.356383   2.0       40.0        34.0                 4
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT6_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   26 -110871.907685  1.567568       22.0        36.0                 4
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT6_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   45 -111508.264417  2.216216       46.0        36.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT6_I5_global_results.csv'}},
#                                        'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   24 -110401.722269  1.189189       14.0        30.0                 4
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT8_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD   BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   41 -111106.1803  1.72973       34.0        30.0                 4
#
#    Total time(s)
# 0              0  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT8_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   28 -111707.211032  1.72973       30.0        34.0                 5
#
#    Total time(s)
# 0              0  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm10kT8_I5_global_results.csv'}}},
#                             '50k': {   'T2': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   31 -533615.118216  1.567568       44.0        14.0                 6
#
#    Total time(s)
# 0              2  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT2_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   26 -532974.223659  1.027027       24.0        14.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT2_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   25 -531618.002134  1.189189       28.0        16.0                 9
#
#    Total time(s)
# 0              2  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT2_I5_global_results.csv'}},
#                                        'T4': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   43 -532943.994149  1.783784       52.0        14.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT4_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   35 -532692.657261  1.945946       52.0        20.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT4_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   40 -533272.110258  2.27027       70.0        14.0                 7
#
#    Total time(s)
# 0              1  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT4_I5_global_results.csv'}},
#                                        'T6': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   54 -535269.255884  3.081081       86.0        28.0                 5
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT6_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   33 -532479.468513  1.405405       38.0        14.0                 4
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT6_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   50 -532509.273453  2.594595       82.0        14.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT6_I5_global_results.csv'}},
#                                        'T8': {   'I10': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   43 -532613.993811  1.891892       50.0        20.0                 4
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT8_I10_global_results.csv'},
#                                                  'I15': {   'data':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   37 -532250.78833  2.108108       56.0        22.0                 4
#
#    Total time(s)
# 0              1  ,
#                                                             'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT8_I15_global_results.csv'},
#                                                  'I5': {   'data':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0   33 -534410.905796  2.108108       52.0        26.0                 6
#
#    Total time(s)
# 0              1  ,
#                                                            'path': '../experiments/local/raw/networks/alarm/phc/alarm50kT8_I5_global_results.csv'}}}}}}

# %%
df_control_alarm_10k = experiments["alarm"]["ges"]["10k"]["data"]
df_control_alarm_50k = experiments["alarm"]["ges"]["50k"]["data"]

# %%
df_control_alarm_50k
# Out:
#    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total time(s)
# 0    8 -529624.355066  0.378378        6.0         8.0              2

# %%
df_pges_alarm_50k_2T_5I = experiments["alarm"]["pges"]["50k"]["T2"]["I5"]["data"]
df_pges_alarm_50k_2T_5I
# Out:
#    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0    6 -528437.800533  0.216216        0.0         8.0                10
#
#    Total time(s)
# 0              3

# %%
df_example = df_pges_alarm_50k_2T_5I - df_control_alarm_50k
df_example
# Out:
#     BDeu Score  SHD  Total iterations  Total time(s)      dfMM  dfMM minus  \
# 0  1186.554533   -2               NaN              1 -0.162162         0.0
#
#    dfMM plus
# 0       -6.0

# %%
df_example = df_example.add_suffix("_delta")
df_example
# Out:
#    BDeu Score_delta  SHD_delta  Total iterations_delta  Total time(s)_delta  \
# 0       1186.554533         -2                     NaN                    1
#
#    dfMM_delta  dfMM minus_delta  dfMM plus_delta
# 0   -0.162162               0.0             -6.0

# %%
pd.concat([df_pges_alarm_50k_2T_5I, df_example], axis=1)
# Out:
#    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
# 0    6 -528437.800533  0.216216        0.0         8.0                10
#
#    Total time(s)  BDeu Score_delta  SHD_delta  Total iterations_delta  \
# 0              3       1186.554533         -2                     NaN
#
#    Total time(s)_delta  dfMM_delta  dfMM minus_delta  dfMM plus_delta
# 0                    1   -0.162162               0.0             -6.0

# %%
# ?pd.concat

# %%
from pathlib import Path
def save_experiment(df, output_path, output_file):    
    output_dir = Path(output_path)
    output_dir.mkdir(parents=True, exist_ok=True)
    df.to_csv(output_dir / output_file)  # can join path elements with / operator

# %%
def delta_score_control_ges(experiments):
    result = {}
    for net in experiments:
        result[net] = {}
        for alg in experiments[net]:
            result[net][alg] = {}
            for size in experiments[net][alg]:
                result[net][alg][size] = {}
                df_experiment = None
                df_control = experiments[net]["ges"][size]["data"]
                if alg != "ges":
                    for thread in experiments[net][alg][size]:
                        result[net][alg][size][thread] = {}
                        for inter in experiments[net][alg][size][thread]:
                            df_experiment = experiments[net][alg][size][thread][inter]["data"]
                            df_result = df_experiment - df_control
                            df_result.drop(["Total iterations"], axis=1, inplace=True)
                            df_result = df_result.add_suffix('_deltaGES')
                             
                            result[net][alg][size][thread][inter] = df_final
                            dir_path = "../experiments/local/clean/networks/" + net + "/" + alg
                            file_name = net + size + thread+ "_" + inter + "_" + "results.csv"
                            save_experiment(df_final, dir_path, file_name )
    return result

# %%
results_control_ges = delta_score_control_ges(experiments)

# %%
experiments["alarm"]["ges"]["10k"]["data"]
# Out:
#    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total time(s)
# 0   16 -110492.244849  1.027027       12.0        26.0              1

# %%
results_control_ges
# Out:
# {'alarm': {'ges': {'10k': {}, '50k': {}},
#   'hc': {'10k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                11
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1338.627806         22                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  },
#     'T4': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                11
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1338.627806         22                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1338.627806         22                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                11
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                11
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1338.627806         22                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -111830.872655  1.783784       32.0        34.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1338.627806         22                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.756757               8.0             20.0  }},
#    '50k': {'T2': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                13
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I10':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -3553.193099         19                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I15':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  },
#     'T4': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                13
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I10':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I15':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  },
#     'T6': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                13
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I10':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I15':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  },
#     'T8': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                13
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I10':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I15':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -533177.548165  1.72973       46.0        18.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -3553.193099         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  }}},
#   'pfhcbes': {'10k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   11 -109670.733751  0.756757        2.0        26.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0        821.511098         -5                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    -0.27027               0.0            -10.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   24 -110557.756724  1.135135       18.0        24.0                 9
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0        -65.511875          8                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.108108              -2.0              6.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   35 -110479.934647  1.351351       28.0        22.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1         12.310201         19                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.324324              -4.0             16.0  },
#     'T4': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   45 -111983.170636  1.891892       26.0        44.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1490.925787         29                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.864865              18.0             14.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   28 -111235.366562  1.513514       26.0        30.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -743.121713         12                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.486486               4.0             14.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   34 -111102.293374  2.162162       40.0        40.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -610.048525         18                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.135135              14.0             28.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   25 -111168.610524  1.621622       24.0        36.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -676.365675          9                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.594595              10.0             12.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   30 -111385.352403  1.675676       40.0        22.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -893.107554         14                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.648649              -4.0             28.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   30 -111847.683346  1.621622       28.0        32.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1355.438497         14                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.594595               6.0             16.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   38 -110981.442702  1.837838       30.0        38.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -489.197853         22                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.810811              12.0             18.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   30 -110886.291218  1.675676       26.0        36.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -394.046369         14                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.648649              10.0             14.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   39 -111640.698619  1.945946       36.0        36.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -1148.453771         23                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.918919              10.0             24.0  }},
#    '50k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   11 -529529.496734  0.486486        6.0        12.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3         94.858333          3                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.108108               4.0              0.0  ,
#      'I10':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   35 -533685.85961  1.837838       38.0        30.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -4061.504543         27                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.459459              22.0             32.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   39 -535553.120535  2.054054       56.0        20.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -5928.765468         31                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.675676              12.0             50.0  },
#     'T4': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   19 -528795.945958  0.756757       14.0        14.0                 9
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1        828.409108         11                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.378378               6.0              8.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   35 -536630.462198  1.783784       54.0        12.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -7006.107131         27                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.405405               4.0             48.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   49 -536447.307654  2.378378       62.0        26.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -6822.952588         41                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0         2.0              18.0             56.0  },
#     'T6': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   25 -532060.262368  1.72973       40.0        24.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2435.907302         17                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              16.0             34.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   24 -531720.525949  1.675676       42.0        20.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2096.170882         16                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.297297              12.0             36.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   28 -530099.994618  1.189189       22.0        22.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2       -475.639552         20                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.810811              14.0             16.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   18 -532762.811722  1.081081       24.0        16.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -3138.456656         10                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703               8.0             18.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   70 -533688.958979  3.243243       98.0        22.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              4      -4064.603913         62                    2
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    2.864865              14.0             92.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   34 -533241.868645  1.837838       56.0        12.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -3617.513579         26                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.459459               4.0             50.0  }}},
#   'pges': {'10k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   17 -110675.386019  0.972973        8.0        28.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1        -183.14117          1                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0   -0.054054               2.0             -4.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   13 -110141.116831  0.594595        6.0        16.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1        351.128017         -3                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0   -0.432432             -10.0             -6.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   32 -111129.283677  1.459459       24.0        30.0                11
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -637.038828         16                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.432432               4.0             12.0  },
#     'T4': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   26 -111050.058523  1.567568       20.0        38.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -557.813674         10                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.540541              12.0              8.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   23 -111007.220105  1.135135       14.0        28.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -514.975256          7                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.108108               2.0              2.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   23 -111837.297253  1.297297       16.0        32.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1345.052404          7                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0     0.27027               6.0              4.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   32 -111532.801004  1.675676       26.0        36.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1040.556155         16                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.648649              10.0             14.0  ,
#      'I10':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   28 -111293.127349  1.72973       24.0        40.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1         -800.8825         12                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703              14.0             12.0  ,
#      'I15':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -111479.649091  1.72973       22.0        42.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -987.404242         11                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703              16.0             10.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   21 -110046.727419  1.351351       14.0        36.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1         445.51743          5                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.324324              10.0              2.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   27 -111877.347033  1.621622       26.0        34.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -1385.102185         11                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.594595               8.0             14.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   34 -112291.861226  2.054054       36.0        40.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -1799.616377         18                    2
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.027027              14.0             24.0  }},
#    '50k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0    6 -528437.800533  0.216216        0.0         8.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3       1186.554533         -2                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0   -0.162162               0.0             -6.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   18 -529978.942184  1.243243       28.0        18.0                 9
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3       -354.587118         10                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.864865              10.0             22.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   11 -531090.598115  0.540541       10.0        10.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -1466.243048          3                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.162162               2.0              4.0  },
#     'T4': {'I5':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   25 -531355.95047  1.567568       40.0        18.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -1731.595403         17                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.189189              10.0             34.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   11 -529366.302438  0.486486        8.0        10.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2        258.052629          3                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.108108               2.0              2.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   22 -531643.351219  1.189189       28.0        16.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              5      -2018.996152         14                    3
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.810811               8.0             22.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   16 -528843.841769  0.648649        8.0        16.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              4        780.513297          8                    2
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0     0.27027               8.0              2.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   16 -529359.546259  0.594595        6.0        16.0                10
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              4        264.808808          8                    2
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.216216               8.0              0.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   17 -530188.016709  1.081081       30.0        10.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              4       -563.661643          9                    2
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703               2.0             24.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   31 -530428.702596  1.891892       54.0        16.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3       -804.347529         23                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.513514               8.0             48.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   25 -532286.177538  1.675676       46.0        16.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -2661.822471         17                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.297297               8.0             40.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   37 -532151.921336  1.405405       38.0        14.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              3      -2527.566269         29                    1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.027027               6.0             32.0  }}},
#   'phc': {'10k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   26 -111178.167331  1.675676       26.0        36.0                 8
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -685.922482         10                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.648649              10.0             14.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   31 -111012.214487  1.513514       30.0        26.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -519.969638         15                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.486486               0.0             18.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   48 -111942.205209  1.837838       38.0        30.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -1449.96036         32                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.810811               4.0             26.0  },
#     'T4': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   21 -110455.555029  1.081081       14.0        26.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0          36.68982          5                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.054054               0.0              2.0  ,
#      'I10':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   42 -112815.15958  2.378378       52.0        36.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -2322.914731         26                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.351351              10.0             40.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   28 -110847.547022  1.513514       24.0        32.0                 3
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -355.302173         12                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.486486               6.0             12.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   45 -111508.264417  2.216216       46.0        36.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1016.019568         29                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.189189              10.0             34.0  ,
#      'I10':    SHD     BDeu Score  dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   32 -111677.356383   2.0       40.0        34.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1185.111534         16                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.972973               8.0             28.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   26 -110871.907685  1.567568       22.0        36.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -379.662837         10                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.540541              10.0             10.0  },
#     'T8': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   28 -111707.211032  1.72973       30.0        34.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0      -1214.966183         12                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703               8.0             18.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   24 -110401.722269  1.189189       14.0        30.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0          90.52258          8                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.162162               4.0              2.0  ,
#      'I15':    SHD   BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   41 -111106.1803  1.72973       34.0        30.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              0       -613.935451         25                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.702703               4.0             22.0  }},
#    '50k': {'T2': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   25 -531618.002134  1.189189       28.0        16.0                 9
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2      -1993.647068         17                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.810811               8.0             22.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   31 -533615.118216  1.567568       44.0        14.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              2       -3990.76315         23                    0
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.189189               6.0             38.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   26 -532974.223659  1.027027       24.0        14.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -3349.868593         18                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    0.648649               6.0             18.0  },
#     'T4': {'I5':    SHD     BDeu Score     dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   40 -533272.110258  2.27027       70.0        14.0                 7
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -3647.755192         32                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.891892               6.0             64.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   43 -532943.994149  1.783784       52.0        14.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -3319.639082         35                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.405405               6.0             46.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   35 -532692.657261  1.945946       52.0        20.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -3068.302194         27                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.567568              12.0             46.0  },
#     'T6': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   50 -532509.273453  2.594595       82.0        14.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2884.918386         42                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    2.216216               6.0             76.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   54 -535269.255884  3.081081       86.0        28.0                 5
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -5644.900818         46                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    2.702703              20.0             80.0  ,
#      'I15':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   33 -532479.468513  1.405405       38.0        14.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2855.113446         25                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.027027               6.0             32.0  },
#     'T8': {'I5':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   33 -534410.905796  2.108108       52.0        26.0                 6
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1       -4786.55073         25                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0     1.72973              18.0             46.0  ,
#      'I10':    SHD     BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   43 -532613.993811  1.891892       50.0        20.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2989.638744         35                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0    1.513514              12.0             44.0  ,
#      'I15':    SHD    BDeu Score      dfMM  dfMM plus  dfMM minus  Total iterations  \
#      0   37 -532250.78833  2.108108       56.0        22.0                 4
#
#         Total time(s)  BDeu Score_delta  SHD_delta  Total time(s)_delta  \
#      0              1      -2626.433263         29                   -1
#
#         dfMM_delta  dfMM minus_delta  dfMM plus_delta
#      0     1.72973              14.0             50.0  }}}}}

# %%
alarm10kT2_I5_global_results
